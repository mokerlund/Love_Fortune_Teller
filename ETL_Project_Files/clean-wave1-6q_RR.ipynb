# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
#read csvs
df1 = pd.read_csv('CSV_files/HCMST_ver_3.csv')
df4 = pd.read_csv('CSV_files/wave_4_supplement.csv')
df5 = pd.read_csv('CSV_files/HCMST_wave_5.csv')
df6 = pd.read_csv('CSV_files/HCMST_wave_6.csv')
# Out:
# C:\Users\Romina\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (76,77,78,79,90,91,92,93,108,150) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # clean df1 (waves 1-3)

# %%
df1['qflag'].value_counts()
# Out:
# partnered                                        3009
# no spouse or partner or otherwise unqualified     993
# Name: qflag, dtype: int64

# %%
disQ_at_wv1 = []

for index, row in df1.iterrows():
    if df1.loc[index, 'qflag'] == "no spouse or partner or otherwise unqualified":
        disQ_at_wv1.append(df1['caseid_new'])

print('length of disQ_at_wv1 list:')
print(len(disQ_at_wv1))
# Out:
# length of disQ_at_wv1 list:
# 993

# %%
#remove rows where people are not in relationship (not qualified)
print(df1['qflag'].value_counts())
print('-----')
df1 = df1[df1.qflag!= "no spouse or partner or otherwise unqualified"]
print(df1['qflag'].value_counts())
# Out:
# partnered                                        3009
# no spouse or partner or otherwise unqualified     993
# Name: qflag, dtype: int64
# -----
# partnered    3009
# Name: qflag, dtype: int64

# %%
wave2_full = df1[['caseid_new',
 'w2_deceased',
 'w2_multiname',
 'w2_panelstat',
 'w2_donotcontact',
 'w2_assigned',
 'w2_f1complete',
 'w2_HCMST_interview_fin_yrmo',
 'w2_duration',
 'w2_xmarry',
 'w2_xss',
 'w2_source',
 'w2_q1',
 'w2_q2',
 'w2_q3',
 'w2_q4',
 'w2_q5',
 'w2_q6',
 'w2_q7',
 'w2_q8',
 'w2_q9',
 'w2_q10',
 'w2_broke_up',
 'w2_days_elapsed'
]]

# %%
wave2_full.insert(1,"qualified?","")
wave2_full.insert(1,"caseid_wave","")

print(wave2_full["qualified?"].value_counts())
print(wave2_full["caseid_wave"].value_counts())
# Out:
#     3009
# Name: qualified?, dtype: int64
#     3009
# Name: caseid_wave, dtype: int64

# %%
for index, row in wave2_full.iterrows():
    wave2_full.loc[index,"qualified?"] = "qualified"
    wave2_full.loc[index,'caseid_wave'] = f'{wave2_full.loc[index,"caseid_new"]}_2'

print(wave2_full["qualified?"].value_counts())
wave2_full
# Out:
# C:\Users\megam\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:480: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# qualified    3009
# Name: qualified?, dtype: int64
#       caseid_new caseid_wave qualified?   w2_deceased w2_multiname  \
# 0          22526     22526_2  qualified  not deceased          NaN
# 1          23286     23286_2  qualified  not deceased          NaN
# 3          26315     26315_2  qualified  not deceased          NaN
# 6          28536     28536_2  qualified  not deceased          NaN
# 7          29584     29584_2  qualified  not deceased          NaN
# ...          ...         ...        ...           ...          ...
# ...

# %%
wv2_w = wave2_full[['caseid_new',
 'caseid_wave', #newly added
'qualified?', #newly added                      
                    
 'w2_broke_up',
 'w2_xmarry',           
 'w2_deceased',
#  'w2_multiname',
 'w2_panelstat',
 'w2_donotcontact',
 'w2_assigned',
 'w2_f1complete',
 'w2_HCMST_interview_fin_yrmo',
#  'w2_duration',
 'w2_xss',
#  'w2_source',
 'w2_q1',
 'w2_q5',
 'w2_q2',
 'w2_q3',
 'w2_q4',
 'w2_q6',
 'w2_q7',
 'w2_q8',
 'w2_q9',
 'w2_q10'
 #'w2_days_elapsed'
]]

# %%
wv2_w.shape
# Out:
# (3009, 22)

# %%
wv2_w
# Out:
#       caseid_new caseid_wave qualified?     w2_broke_up  w2_xmarry  \
# 0          22526     22526_2  qualified  still together  partnered
# 1          23286     23286_2  qualified  still together    married
# 3          26315     26315_2  qualified        broke up  partnered
# 6          28536     28536_2  qualified  still together  partnered
# 7          29584     29584_2  qualified  still together    married
# ...          ...         ...        ...             ...        ...
# 3995     4621371   4621371_2  qualified  still together    married
# 3996     4622461   4622461_2  qualified  still together    married
# 3999     4626536   4626536_2  qualified             NaN        NaN
# 4000     4627251   4627251_2  qualified             NaN        NaN
# 4001     4628251   4628251_2  qualified  still together    married
#
#        w2_deceased           w2_panelstat                    w2_donotcontact  \
# 0     not deceased  withdrawn kn panelist                    all other cases
# ...

# %% [markdown]
# # WAVE 3

# %%
wave3_full = df1[['caseid_new',
 'w3_broke_up',
 'w3_xpartnered',
 'w3_xdeceased',
 'w3_multiname',
 'w3_xss',
 'w3_xlast',
 'w3_xyear',
 'w3_xmonth',
 'w3_xqualified',
 'w3_status',
 'w3_complete',
 'w3_source',
 'w3_HCMST_interview_fin_yrmo',
 'w3_days_elapsed',
 'w3_duration',
 'w3_xmarry',
 'w3_xtype',
 'w3_q1',
 'w3_q2',
 'w3_q3',
 'w3_q4',
 'w3_mbtiming_year',
 'w3_mbtiming_month',
 'w3_q5',
 'w3_q6',
 'w3_q7',
 'w3_q8',
 'w3_q9',
 'w3_q10',
 'w3_nonmbtiming_year',
 'w3_nonmbtiming_month'
]]

# %%
print(wave3_full['w3_xqualified'].value_counts())
print('-----------------')

wave3_full.insert(1,"qualified?","")
wave3_full.insert(1,"caseid_wave","")

print(wave3_full["qualified?"].value_counts())
print(wave3_full["caseid_wave"].value_counts())
# Out:
# qualified for wave 3      2689
# unqualified for wave 3     320
# Name: w3_xqualified, dtype: int64
# -----------------
#     3009
# Name: qualified?, dtype: int64
#     3009
# Name: caseid_wave, dtype: int64

# %%
for index, row in wave3_full.iterrows():
    if wave3_full.loc[index,'w3_xqualified'] == "qualified for wave 3":
        wave3_full.loc[index,"qualified?"] = "qualified"
    elif wave3_full.loc[index,'w3_xqualified'] == "unqualified for wave 3":
        wave3_full.loc[index,"qualified?"] = "disqualified"
    wave3_full.loc[index,'caseid_wave'] = f'{wave3_full.loc[index,"caseid_new"]}_3'

print(wave3_full["qualified?"].value_counts())
wave3_full
# Out:
# qualified       2689
# disqualified     320
# Name: qualified?, dtype: int64
#       caseid_new caseid_wave    qualified?     w3_broke_up  \
# 0          22526     22526_3     qualified  still together
# 1          23286     23286_3     qualified  still together
# 3          26315     26315_3  disqualified             NaN
# 6          28536     28536_3     qualified  still together
# 7          29584     29584_3     qualified  still together
# ...          ...         ...           ...             ...
# 3995     4621371   4621371_3     qualified  still together
# 3996     4622461   4622461_3     qualified             NaN
# 3999     4626536   4626536_3     qualified             NaN
# 4000     4627251   4627251_3     qualified             NaN
# 4001     4628251   4628251_3     qualified  still together
#
#                           w3_xpartnered  w3_xdeceased w3_multiname w3_xss  \
# 0      Qualified for follow-up at wave3  not deceased          NaN    yes
# ...

# %%
wv3_w = wave3_full[['caseid_new', 
 'caseid_wave', #newly added
'qualified?', #newly added                   
                    
 'w3_broke_up',
 'w3_xmarry',
 'w3_xdeceased',
'w3_xpartnered',
#  'w3_multiname',
 'w3_xss',
 'w3_xlast',
 'w3_xyear',
#  'w3_xmonth',
 'w3_xqualified',
 'w3_status',
 'w3_complete', # complete wave 3 survey?
#  'w3_source', # online or telephone interview?
 'w3_HCMST_interview_fin_yrmo', # year/month of 3rd wave interview
 'w3_days_elapsed',
#  'w3_duration',
 'w3_xtype', # same-sex or heterosexual?
 'w3_q1', # still married?
 'w3_q2', # still living together?
 'w3_q3', # how did marriage end?                  
 'w3_q4', # who wanted marriage to end more?
 'w3_mbtiming_year',
#  'w3_mbtiming_month',
 'w3_q5', # still in romantic relationship with partner?
 'w3_q6', # currently living with partner?
 'w3_q7', # have you and partner gotten married in last year
 'w3_q8',
  'w3_q9', # how did relationship end
  'w3_q10', # who wanted to break up more
  'w3_nonmbtiming_year' ### year of breakup
#  'w3_nonmbtiming_month'
]]

# %%
# print(w3.shape)
# w3 = w3.dropna(how='all',axis=0)
# print(w3.shape)

# %%
wv3_w
# Out:
#       caseid_new caseid_wave    qualified?     w3_broke_up  w3_xmarry  \
# 0          22526     22526_3     qualified  still together  Partnered
# 1          23286     23286_3     qualified  still together    Married
# 3          26315     26315_3  disqualified             NaN        NaN
# 6          28536     28536_3     qualified  still together  Partnered
# 7          29584     29584_3     qualified  still together    Married
# ...          ...         ...           ...             ...        ...
# 3995     4621371   4621371_3     qualified  still together    Married
# 3996     4622461   4622461_3     qualified             NaN        NaN
# 3999     4626536   4626536_3     qualified             NaN        NaN
# 4000     4627251   4627251_3     qualified             NaN        NaN
# 4001     4628251   4628251_3     qualified  still together    Married
#
#       w3_xdeceased                      w3_xpartnered w3_xss     w3_xlast  \
# ...

# %% [markdown]
# # Wave 4

# %%
wave4_full = df4[[ 'caseid_new',
 'w4_xqualified',
 'w4_status',
 'w4_complete',
  'w4_source',
  'w4_duration',
 'w4_HCMST_interview_fin_yrmo',
 'w4_xtype',
 'w4_xyear',
 'w4_xmonth',
 'w4_xmarry',
 'w4_xlast',
 'w4_xwave1_month',
 'w4_xcivil',
 'w4_xss',
 'w4_q1',
 'w4_q2',
 'w4_quality',
 'w4_attractive',
 'w4_attractive_partner',
 'w4_q3',
 'w4_q4',
 'w4_mbtiming_year',
 'w4_mbtiming_month',
 'w4_q5',
 'w4_q6',
 'w4_q7',
 'w4_mar_year',
 'w4_mar_month',
 'w4_civ_year',
 'w4_q8_a',
 'w4_q8_b',
 'w4_q9',
 'w4_q10',
 'w4_nonmbtiming_year',
 'w4_nonmbtiming_month',
 'relationship_quality_w4',
 'w4_broke_up',
 'w234_combo_breakup'
]]

# %%
print(wave4_full['w4_xqualified'].value_counts())
print('-----------------')

wave4_full.insert(1,"qualified?","")
wave4_full.insert(1,"caseid_wave","")

print(wave4_full["qualified?"].value_counts())
print(wave4_full["caseid_wave"].value_counts())
# Out:
# qualified for wave 4      2557
# unqualified for wave 4    1445
# Name: w4_xqualified, dtype: int64
# -----------------
#     4002
# Name: qualified?, dtype: int64
#     4002
# Name: caseid_wave, dtype: int64

# %%
for index, row in wave4_full.iterrows():
    if wave4_full.loc[index,'w4_xqualified'] == "qualified for wave 4":
        wave4_full.loc[index,"qualified?"] = "qualified"
    elif wave4_full.loc[index,'w4_xqualified'] == "unqualified for wave 4":
        wave4_full.loc[index,"qualified?"] = "disqualified"
    wave4_full.loc[index,'caseid_wave'] = f'{wave4_full.loc[index,"caseid_new"]}_4'

print(wave4_full["qualified?"].value_counts())
wave4_full
# Out:
# qualified       2557
# disqualified    1445
# Name: qualified?, dtype: int64
#       caseid_new caseid_wave    qualified?           w4_xqualified  \
# 0          22526     22526_4     qualified    qualified for wave 4
# 1          23286     23286_4     qualified    qualified for wave 4
# 2          25495     25495_4  disqualified  unqualified for wave 4
# 3          26315     26315_4  disqualified  unqualified for wave 4
# 4          27355     27355_4  disqualified  unqualified for wave 4
# ...          ...         ...           ...                     ...
# 3997     4623505   4623505_4  disqualified  unqualified for wave 4
# 3998     4625902   4625902_4  disqualified  unqualified for wave 4
# 3999     4626536   4626536_4     qualified    qualified for wave 4
# 4000     4627251   4627251_4     qualified    qualified for wave 4
# 4001     4628251   4628251_4     qualified    qualified for wave 4
#
#         w4_status w4_complete w4_source  w4_duration  \
# ...

# %%
wv4_w = wave4_full[['caseid_new',
'caseid_wave', #newly added
'qualified?', #newly added
                    
'w4_broke_up',
 'w234_combo_breakup',
 'w4_xqualified',
 'w4_status',
 'w4_complete',
#  'w4_source',
#  'w4_duration',
 'w4_HCMST_interview_fin_yrmo',
 'w4_xtype',
 'w4_xyear',
# 'w4_xmonth',
# 'w4_xmarry',
 'w4_xlast',
# 'w4_xwave1_month',
# 'w4_xcivil',
 'w4_xss',
 'w4_q1',
 'w4_q2',
 'w4_quality',
'relationship_quality_w4',
 'w4_attractive',
 'w4_attractive_partner',
 'w4_q3',
 'w4_q4',
# 'w4_mbtiming_year',
 'w4_mbtiming_month',
 'w4_q5',
 'w4_q6',
 'w4_q7',
# 'w4_mar_year',
# 'w4_mar_month',
 'w4_civ_year',
 'w4_q8_a',
 'w4_q8_b',
 'w4_q9',
 'w4_q10',
# 'w4_nonmbtiming_year',
# 'w4_nonmbtiming_month',
]]

# %%
wv4_w
# Out:
#       caseid_new caseid_wave    qualified?     w4_broke_up  \
# 0          22526     22526_4     qualified  still together
# 1          23286     23286_4     qualified  still together
# 2          25495     25495_4  disqualified             NaN
# 3          26315     26315_4  disqualified             NaN
# 4          27355     27355_4  disqualified             NaN
# ...          ...         ...           ...             ...
# 3997     4623505   4623505_4  disqualified             NaN
# 3998     4625902   4625902_4  disqualified             NaN
# 3999     4626536   4626536_4     qualified             NaN
# 4000     4627251   4627251_4     qualified             NaN
# 4001     4628251   4628251_4     qualified  still together
#
#                                      w234_combo_breakup  \
# 0     still together at w4, or some follow-up w/o br...
# 1     still together at w4, or some follow-up w/o br...
# 2                                                   NaN
# ...

# %% [markdown]
# # Wave 5

# %%
wave5_full = df5[[ 'caseid_new',
 'w5_duration',
 'w5_source',
 'w5_complete',
 'w5_status',
 'w5x_qualified',
 'w5x_marry',
 'w5x_last',
 'w5x_year',
 'w5x_civil',
 'w5x_month',
 'w5x_civyear',
 'w5x_civmonth',
 'w5_q1',
 'w5_q2',
 'w5_sex_frequency',
 'w5_p_monogamy',
 'w5_identity',
 'w5_outness',
 'w5_q3',
 'w5_q4',
 'w5_mbtiming_month',
 'w5_mbtiming_year',
 'w5_q5',
 'w5_q6',
 'w5_q7',
 'w5_mar_year',
 'w5_mar_month',
 'w5_q8',
 'w5_civ_year',
 'w5_civ_month',
 'w5_q9',
 'w5_q10',
 'w5_nonmbtiming_year',
 'w5_nonmbtiming_month',
 'w5_broke_up',
 'w5_HCMST_interview_fin_yrmo',
 'w2345_combo_breakup',
 'responded_to_w234or5'
]]

# %%
print('-----------------')
print(wave5_full['w5x_qualified'].value_counts())
# Out:
# -----------------
# qualified for wave 5        2444
# not qualified for wave 5    1558
# Name: w5x_qualified, dtype: int64

# %%
wave5_full.insert(1,"qualified?","")
wave5_full.insert(1,"caseid_wave","")
print(wave5_full["qualified?"].value_counts())
print(wave5_full["caseid_wave"].value_counts())
# Out:
#     4002
# Name: qualified?, dtype: int64
#     4002
# Name: caseid_wave, dtype: int64

# %%
for index, row in wave5_full.iterrows():
    if wave5_full.loc[index,'w5x_qualified'] == "qualified for wave 5":
        wave5_full.loc[index,"qualified?"] = "qualified"
    elif wave5_full.loc[index,'w5x_qualified'] == "not qualified for wave 5":
        wave5_full.loc[index,"qualified?"] = "disqualified"
    wave5_full.loc[index,'caseid_wave'] = f'{wave5_full.loc[index,"caseid_new"]}_5'
print(wave5_full["qualified?"].value_counts())
# Out:
# qualified       2444
# disqualified    1558
# Name: qualified?, dtype: int64

# %%
wv5_w = wave5_full[['caseid_new',
'caseid_wave', #newly added
'qualified?', #newly added

                    
#  'w5_duration',
#  'w5_source',
 'w5_complete',
 'w5_status', # important (better than w5_complete)
 'w5x_qualified',
 'w5x_marry',
 'w5x_last',
 'w5x_year',
 'w5x_civil',
 'w5x_month',
 'w5x_civyear',
#  'w5x_civmonth',
 'w5_q1',
 'w5_q2',
 'w5_sex_frequency',
 'w5_p_monogamy',
 'w5_identity',
 'w5_outness',
  'w5_q3',
  'w5_q4',
  'w5_mbtiming_month',
 'w5_mbtiming_year',
 'w5_q5',
 'w5_q6',
 'w5_q7',
 'w5_mar_year',
 'w5_mar_month',
 'w5_q8',
 'w5_civ_year',
 'w5_civ_month',
  'w5_q9',
  'w5_q10',
 'w5_nonmbtiming_year',
 'w5_nonmbtiming_month',
 'w5_broke_up',
 'w5_HCMST_interview_fin_yrmo',
 'w2345_combo_breakup',
 'responded_to_w234or5',
]]

# %%
wv5_w
# Out:
#       caseid_new caseid_wave    qualified?                 w5_complete  \
# 0          22526     22526_5     qualified            wave 5 completed
# 1          23286     23286_5     qualified            wave 5 completed
# 2          25495     25495_5  disqualified                         NaN
# 3          26315     26315_5  disqualified                         NaN
# 4          27355     27355_5  disqualified                         NaN
# ...          ...         ...           ...                         ...
# 3997     4623505   4623505_5  disqualified                         NaN
# 3998     4625902   4625902_5  disqualified                         NaN
# 3999     4626536   4626536_5     qualified  eligible but not completed
# 4000     4627251   4627251_5     qualified  eligible but not completed
# 4001     4628251   4628251_5     qualified  eligible but not completed
#
#         w5_status             w5x_qualified           w5x_marry  w5x_last  \
# ...

# %% [markdown]
# # Wave 6

# %%
#everything
wave6_full = df6[['caseid_new',
 'xw6_year',
 'xw6_month',
 'xw6_last',
 'xw6_marry',
 'w6_still_mar',
 'w6_live_together',
 'w6_otherdate',
 'w6_how_many',
  'w6_otherdate_app',
 'w6_how_many_app',
 'w6_relationship_end_mar',
 'w6_who_breakup',
 'w6_mbtiming_Year',
 'w6_mbtiming_Month',
 'w6_partner_passaway_Year',
 'w6_partner_passaway_Month',
  'w6_otherdate_B',
  'w6_how_many_B',
  'w6_otherdate_app_B',
  'w6_how_many_app_B',
 'w6_still_rel',
 'w6_live_together_C',
 'w6_got_married',
 'w6_martiming_Year',
  'w6_martiming_Month',
 'w6_otherdate_C',
 'w6_how_many_C',
 'w6_otherdate_app_C',
 'w6_how_many_app_C',
 'w6_relationship_end_nonmar',
 'w6_who_breakup_C',
 'w6_nonmbtiming_Year',
  'w6_nonmbtiming_Month',
 'w6_partner_passaway_C_Year',
  'w6_partner_passaway_C_Month',
  'w6_otherdate_C2',
  'w6_how_many_C2',
  'w6_otherdate_app_C2',
  'w6_how_many_app_C2',
 'w6_relate_status',
 'w6_broke_up',
 'w6_met_through_friends',
 'w6_met_through_family',
 'w6_met_online',
 'w6_met_through_as_coworkers',
 'w6_met_online_dating',
 'w6_met_bar_restaurant',
'w6_how_met_story_length',
 'w6_combo_live_together',
 'w6_otherdate_combo',
 'w6_how_many_combo',
 'w6_otherdate_app_combo',
 'w6_how_many_app_combo',
 'w6_HCMST_yrmo'    
]]

# %%
wave6_full.insert(1,"qualified?","")
wave6_full.insert(1,"caseid_wave","")

print(wave6_full["qualified?"].value_counts())
print(wave6_full["caseid_wave"].value_counts())
# Out:
#     640
# Name: qualified?, dtype: int64
#     640
# Name: caseid_wave, dtype: int64

# %%
for index, row in wave6_full.iterrows():
#     if wave6_full.loc[index,'w6x_qualified'] == "qualified for wave 6":
#         wave6_full.loc[index,"qualified?"] = "qualified"
#     elif wave6_full.loc[index,'w6x_qualified'] == "not qualified for wave 6":
#         wave6_full.loc[index,"qualified?"] = "disqualified"
    wave6_full.loc[index,'caseid_wave'] = f'{wave6_full.loc[index,"caseid_new"]}_6'
print(wave6_full["qualified?"].value_counts())
# Out:
#     640
# Name: qualified?, dtype: int64

# %%
wv6_w = wave6_full[['caseid_new',
'caseid_wave',
                    
 'xw6_year',
 'xw6_month',
 'xw6_last',
 'xw6_marry',
 'w6_still_mar',
 'w6_live_together',
 'w6_otherdate',
 'w6_how_many',
#  'w6_otherdate_app',
 'w6_how_many_app',
 'w6_relationship_end_mar',
 'w6_who_breakup',
 'w6_mbtiming_Year',
 'w6_mbtiming_Month',
 'w6_partner_passaway_Year',
 'w6_partner_passaway_Month',
#  'w6_otherdate_B',
#  'w6_how_many_B',
#  'w6_otherdate_app_B',
#  'w6_how_many_app_B',
 'w6_still_rel',
 'w6_live_together_C',
 'w6_got_married',
 'w6_martiming_Year',
#  'w6_martiming_Month',
 'w6_otherdate_C',
 'w6_how_many_C',
 'w6_otherdate_app_C',
 'w6_how_many_app_C',
 'w6_relationship_end_nonmar',
 'w6_who_breakup_C',
 'w6_nonmbtiming_Year',
#  'w6_nonmbtiming_Month',
 'w6_partner_passaway_C_Year',
#  'w6_partner_passaway_C_Month',
#  'w6_otherdate_C2',
#  'w6_how_many_C2',
#  'w6_otherdate_app_C2',
#  'w6_how_many_app_C2',
 'w6_relate_status',
 'w6_broke_up',
 'w6_met_through_friends',
 'w6_met_through_family',
 'w6_met_online',
 'w6_met_through_as_coworkers',
 'w6_met_online_dating',
 'w6_met_bar_restaurant',
#  'w6_how_met_story_length',
 'w6_combo_live_together',
 'w6_otherdate_combo',
 'w6_how_many_combo',
 'w6_otherdate_app_combo',
 'w6_how_many_app_combo',
 'w6_HCMST_yrmo'    
]]

# %%
wv6_w
# Out:
#      caseid_new caseid_wave  xw6_year xw6_month  xw6_last           xw6_marry  \
# 0         22526     22526_6      2014  December         3  unmarried partners
# 1         28536     28536_6      2014  December         3  unmarried partners
# 2         29584     29584_6      2014  December         3             married
# 3         48225     48225_6      2014  December         3             married
# 4         49731     49731_6      2014  December         3             married
# ..          ...         ...       ...       ...       ...                 ...
# 635     4563631   4563631_6      2014  November         3             married
# 636     4583501   4583501_6      2015     March         2             married
# 637     4597381   4597381_6      2013     March         4             married
# 638     4613511   4613511_6      2014  December         3             married
# 639     4621371   4621371_6      2014  December         3             married
#
# ...

# %%
print(f'wave2 table shape: {wv2_w.shape}')
print(f'wave3 table shape: {wv3_w.shape}')
print(f'wave4 table shape: {wv4_w.shape}')
print(f'wave5 table shape: {wv5_w.shape}')
print(f'wave6 table shape: {wv6_w.shape}')
# Out:
# wave2 table shape: (3009, 22)
# wave3 table shape: (3009, 28)
# wave4 table shape: (4002, 30)
# wave5 table shape: (4002, 38)
# wave6 table shape: (640, 43)

# %%
print(wv2_w['qualified?'].value_counts())
print('-----------------')
print(wv3_w['qualified?'].value_counts())
print('-----------------')
print(wv4_w['qualified?'].value_counts())
print('-----------------')
print(wv5_w['qualified?'].value_counts())
# Out:
# qualified    3009
# Name: qualified?, dtype: int64
# -----------------
# qualified       2689
# disqualified     320
# Name: qualified?, dtype: int64
# -----------------
# qualified       2557
# disqualified    1445
# Name: qualified?, dtype: int64
# -----------------
# qualified       2444
# disqualified    1558
# Name: qualified?, dtype: int64

# %% [markdown]
# # Sqlite

# %%
connection_string = "Relationship_survey.sqlite"
engine2 = create_engine(f'sqlite:///{connection_string}')
engine2.table_names() # now it's empty
# Out:
# []

# %%
wv2_w.to_sql(name="wv2_w", con=engine2, if_exists='replace', index=True)
wv3_w.to_sql(name="wv3_w", con=engine2, if_exists='replace', index=True)
wv4_w.to_sql(name="wv4_w", con=engine2, if_exists='replace', index=True)
wv5_w.to_sql(name="wv5_w", con=engine2, if_exists='replace', index=True)
wv6_w.to_sql(name="wv6_w", con=engine2, if_exists='replace', index=True)
#wv2_w.to_sql(name="wv1_pp", con=engine2, if_exists='replace', index=True)
engine2.table_names()
# Out:
# ['wv2_w', 'wv3_w', 'wv4_w', 'wv5_w', 'wv6_w']

# %%
# check if data has been stored properly 

sqlite_wv2_w=engine2.execute("SELECT * FROM wv2_w").fetchall()
for elem in sqlite_wv2_w[0:5]:
    print(elem)
    print("\n")
# Out:
# (0, 22526, '22526_2', 'qualified', 'still together', 'partnered', 'not deceased', 'withdrawn kn panelist', 'all other cases', 'assigned to survey', 'completed followup survey', 201003.0, 'yes, qualified to ask about new domestic parterships', None, 'yes', None, None, None, 'yes', 'no, did not marry [partner]', 'no, we have not gotten a domestic partnership or civil union agreement', None, None)
#
#
# (1, 23286, '23286_2', 'qualified', 'still together', 'married', 'not deceased', 'withdrawn kn panelist', 'all other cases', 'assigned to survey', 'completed followup survey', 201003.0, 'no', 'yes', None, 'yes', None, None, None, None, None, None, None)
#
#
# (3, 26315, '26315_2', 'qualified', 'broke up', 'partnered', 'not deceased', 'withdrawn kn panelist', 'all other cases', 'assigned to survey', 'completed followup survey', 201003.0, 'yes, qualified to ask about new domestic parterships', None, 'no', None, None, None, None, None, None, 'we broke up', 'i wanted to break up more')
#
#
# ...
